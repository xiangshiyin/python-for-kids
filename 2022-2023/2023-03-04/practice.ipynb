# %% [markdown]
# # Demo

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/xiangshiyin/python-for-kids/blob/main/2022-2023/2023-03-04/practice.ipynb)

# %% [markdown]
# ## Recap of Last Class

# %% [markdown]
# ### Draw a moving plot with `matplotlib`

# %%
# %matplotlib notebook
# the command above will lead to interactive plots embedded within the notebook

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()
x = np.linspace(-10, 10, 1000)
line, = ax.plot(x, x)


ax.axvline(x=0, c="red", label="x=0")
ax.axhline(y=0, c="yellow", label="y=0")

def animate(i):
    line.set_ydata(x + i/10)  # update the data
    return line,

ani = animation.FuncAnimation(fig, animate, frames=100, interval=1000, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %% [markdown]
# ## Compare the trends of different math expressions
#
# Here are the candidates
# - $y_0 = x$
# - $y_1 = 50x$
# - $y_2 = x^2$
# - $y_3 = x^3$
# - $y_4 = 2^x$

# %%
import matplotlib.pyplot as plt
import numpy as np

xs = np.linspace(-200, 200, 1000)
y0 = []
y1 = []
y2 = []
y3 = []
y4 = []

# populate all the y values
for x in xs:
    y0.append(x)
    y1.append(50 * x)
    y2.append(x ** 2)
    y3.append(x ** 3)
    y4.append(2 ** x)

# make the plot
plt.plot(xs,y0,label='$y_0$')
plt.plot(xs,y1,label='$y_1$')
plt.plot(xs,y2,label='$y_2$')
# plt.plot(xs,y3,label='$y_3$')
# plt.plot(xs,y4,label='$y_4$')
plt.vlines(x=0, ymax=1000, ymin=-1000)
# plt.xlim(-3,3)
# plt.ylim(-10,10)
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y4[:10]
# Out:
# [0.0009765625,
#  0.000990208545333284,
#  0.0010040452743690835,
#  0.0010180753516357305,
#  0.0010323014788944777,
#  0.0010467263956597743,
#  0.0010613528797268137,
#  0.00107618374770645,
#  0.001091221855567591,
#  0.0011064700991871704]
